# %% [markdown]
# # Jupyter Notebook Starter
#
# Welcome to your new notebook! This is a starter template.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Libraries imported successfully!")

# %%
# Example plot
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave")
plt.show()
